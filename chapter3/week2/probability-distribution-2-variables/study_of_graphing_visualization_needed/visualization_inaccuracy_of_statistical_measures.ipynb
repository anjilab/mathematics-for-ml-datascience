# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import utils
# %matplotlib widget

# %%
df_anscombe = pd.read_csv('df_anscombe.csv')

# %%
df_anscombe.head()
# Out:
#       x     y  group
# 0  10.0  8.04      1
# 1   8.0  6.95      1
# 2  13.0  7.58      1
# 3   9.0  8.81      1
# 4  11.0  8.33      1

# %%
df_anscombe.group.nunique() # from group column, unique values
# Out:
# 4

# %% [markdown]
# ## # finds all statistical measures of the dataset.
# We can observe that all the groups in the dataset possess same or similar or nearly equal to statistical value like mean, std, in x & y.
# No particular distinction. by values we can say they are similar.

# %%
df_anscombe.groupby('group').describe()
# Out:
#           x                                               y            \
#       count mean       std  min  25%  50%   75%   max count      mean
# group
# 1      11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# 2      11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500909
# 3      11.0  9.0  3.316625  4.0  6.5  9.0  11.5  14.0  11.0  7.500000
# 4      11.0  9.0  3.316625  8.0  8.0  8.0   8.0  19.0  11.0  7.500909
#
#
#             std   min    25%   50%   75%    max
# group
# 1      2.031568  4.26  6.315  7.58  8.57  10.84
# 2      2.031657  3.10  6.695  8.14  8.95   9.26
# 3      2.030424  5.39  6.250  7.11  7.98  12.74
# 4      2.030579  5.25  6.170  7.04  8.19  12.50

# %%
df_anscombe.groupby('group').corr() # correlation matrix
# Out:
#                 x         y
# group
# 1     x  1.000000  0.816421
#       y  0.816421  1.000000
# 2     x  1.000000  0.816237
#       y  0.816237  1.000000
# 3     x  1.000000  0.816287
#       y  0.816287  1.000000
# 4     x  1.000000  0.816521
#       y  0.816521  1.000000

# %% [markdown]
# # Visualizing
# After we visualize, though data have nearly same or similar values, we can find the curves different.
# 1. Group 3 would have linear relationship between x & y if outlier was not there.
# 2. Group 4 would have constant relationship between x & y if outlier was not present.
# 3. Group 1 has linear relationship between x & y and also no outlier.
# 4. Group 2 has non linear pattern so correlation coefficient cannot be used.

# %%
utils.plot_anscombes_quartet()

# %%
df_datasaurus = pd.read_csv("datasaurus.csv")
utils.plot_datasaurus()
