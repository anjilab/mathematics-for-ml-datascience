# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
people_number = np.array([1,2,3,4,5,10,20,23,30,50,100,365])
probability = []
for i in people_number: 
    print(i,'here')
    outcome_each_people_birthday_not_on_same_day =  (365-i)/365
    print(outcome_each_people_birthday_not_on_same_day)
    probability.append(outcome_each_people_birthday_not_on_same_day)
    

plt.plot(probability,people_number)
# Out:
# 1 here
# 0.9972602739726028
# 2 here
# 0.9945205479452055
# 3 here
# 0.9917808219178083
# 4 here
# 0.989041095890411
# 5 here
# 0.9863013698630136
# 10 here
# 0.9726027397260274
# 20 here
# 0.9452054794520548
# 23 here
# 0.936986301369863
# 30 here
# 0.9178082191780822
# 50 here
# 0.863013698630137
# 100 here
# 0.726027397260274
# 365 here
# 0.0
