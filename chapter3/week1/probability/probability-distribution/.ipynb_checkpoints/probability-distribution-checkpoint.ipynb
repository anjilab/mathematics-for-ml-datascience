# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# When coin is flipped 3 times, X=NO OF HEADS, P(X) ,HERE X = RANDOM VARIABLE and its possible values are {0,1,2,3}, P(X=1) is an event.

# %%
# Discrete distribution
x = np.array([0,1,2,3])
p_x = np.array([1/8,3/8,3/8,1/8])

plt.bar(x,p_x)
# Out:
# <BarContainer object of 4 artists>

# %%
# Cumulative distribution
x = np.array([0,1,2,3])
p_x = np.array([1/8,3/8,3/8,1/8])
c_x = np.array([1/8, (1/8+3/8) , (1/8+3/8+3/8) , 1])
plt.bar(x,c_x)
# Out:
# <BarContainer object of 4 artists>

# %%
mu, sigma = 2, 0.1 # mean and standard deviation
s = np.random.normal(mu, sigma, 10000)
count, bins, ignored = plt.hist(s, 30, density=True)
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *
               np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
         linewidth=2, color='r')
plt.show()
# Out:
# [0.04084565 0.04538405 0.09530651 0.16792099 0.24961229 0.33130358
#  0.68529919 0.88045062 1.22536941 1.72005558 2.251049   2.83650327
#  3.23134453 3.78502996 4.09364152 3.93479734 3.76233794 3.4673416
#  3.05434672 2.76842719 2.13758886 1.57936502 1.13913971 0.7806057
#  0.49468617 0.30861156 0.14069056 0.09530651 0.03630724 0.04538405] [1.6630344  1.68506857 1.70710274 1.72913692 1.75117109 1.77320526
#  1.79523943 1.8172736  1.83930777 1.86134195 1.88337612 1.90541029
#  1.92744446 1.94947863 1.9715128  1.99354698 2.01558115 2.03761532
#  2.05964949 2.08168366 2.10371783 2.12575201 2.14778618 2.16982035
#  2.19185452 2.21388869 2.23592286 2.25795704 2.27999121 2.30202538
#  2.32405955]
