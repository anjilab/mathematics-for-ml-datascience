# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
vector_a = np.array([3,1]).reshape((2,1))
# print(vector_a.shape, vector_a)
vector_b = np.array([1,2]).reshape((2,1))

vector_matrix = np.hstack([vector_a,vector_b])
linear_transformation_one = np.dot(vector_matrix,np.array([0,0]))

print(linear_transformation_one.shape,linear_transformation_one)
origin = np.array([[0, 0],[0, 0]])
plt.quiver(*origin, vector_a, vector_b, color=['r','b'], scale=10)
plt.quiver(*origin,linear_transformation_one, color=['g'], scale=10)




plt.show()
# Out:
# (2,) [0 0]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 11
#       9 origin = np.array([[0, 0],[0, 0]])
#      10 plt.quiver(*origin, vector_a, vector_b, color=['r','b'], scale=10)
# ---> 11 plt.quiver(*origin, vector_matrix,linear_transformation_one, color=['g'], scale=10)
#      16 plt.show()
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/pyplot.py:2843, in quiver(data, *args, **kwargs)
#    2841 @_copy_docstring_and_deprecators(Axes.quiver)
#    2842 def quiver(*args, data=None, **kwargs):
# -> 2843     __ret = gca().quiver(
#    2844         *args, **({"data": data} if data is not None else {}),
#    2845         **kwargs)
#    2846     sci(__ret)
#    2847     return __ret
#
# File ~/Library/Python/3.9/lib/python/site-packages/matplotlib/__init__.py:1446, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
# ...
